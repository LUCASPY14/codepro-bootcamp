# %%
#print ('hola Lucas23')
# Out:
# hola Lucas23

# %% [markdown]
# # crear un diccionario
#
# 1- crear el diccionario 'clientes' -----> clientes = {}
# 2- pedir al usuario el 'nombre' -----> con input() -----> agregar al diccionario ----> clientes ['nombre' : 'input('ingrese su nombre')]
# 3- imprimir el diccionario
# 4- pedir al usuario su 'edad'  ---> con input () ------> agregar al diccionario ----> clientes [ 'edad' : 'input ('ingrese su edad')]
# 5- imprimir el diccionario
# 6- pedir el usuario su 'sexo' --> con input () ----> agregar al diccionario  ------ > clientes [ 'sexo' : input('ingrese su sexo:')]
# 7- imprimir el diccionario
# 8- pedir al usuario su telefono ----> con input()-----> agregar al diccionario --- > clientes [ 'telefono' : input('ingrese su telefono)]
# 9- imprimir el diccionario
# 10- pedir al usuario 'correo electronico' ---> con input()  ---> agregar al diccionario -----> clientes ['correo electronico' : input(ingrese su correo electronico)]
# 11- imprimir el diccionario

# %%
clientes = {}
clientes['nombre'] = input("ingrese su nombre:")
print(clientes)
clientes['edad'] = input ("ingrese su edad:")
print(clientes)
clientes['sexo'] = input ('ingrese su sexo:')
print (clientes)
clientes['telefono'] = input('ingrese su telefono:')
print(clientes)
clientes['correo_electronico'] = input('ingrese su correo electronico:')
print(clientes)
# Out:
# {'nombre': 'diana'}
# {'nombre': 'diana', 'edad': '43'}
# {'nombre': 'diana', 'edad': '43', 'sexo': 'femenino'}
# {'nombre': 'diana', 'edad': '43', 'sexo': 'femenino', 'telefono': '0985-568963'}
# {'nombre': 'diana', 'edad': '43', 'sexo': 'femenino', 'telefono': '0985-568963', 'correo_electronico': 'diana_villa@hotmail.com'}

# %% [markdown]
# # Crear una tarjeta personal. El usuario (mediante input) puede elegir:
#
# 1- Crear datos nuevos
# 2- Modificar datos
# 3- Eliminar datos
#
# # crear una tarjeta personal
# tarjeta_personal = {"nombre" : "lucas", "apellido" : "gimenez", "telefono" : "0985-350656", "direccion" : "lambare"}
#
# 2- el usuario puede crear datos nuevos ----> tarjeta_personal[clave = input ('ingrese dato nuevo'): 'value = input ('ingrese dato nuevo)]
# 3- el usuario puede modificar los datos ---> tarjeta_personal [ "clave" ] = Input('ingrese el nuevo valor')
# 4- el usuario puede eliminar los datos  ----> con .pop(clave)   ----> tarjeta_personal.pop(clave)

# %%
tarjeta_personal = {"nombre" : "lucas", "apellido": "gimenez", "telefono": "0985-350656", "direccion":"lambare"}


#tarjeta_personal ["nombre"] = 'nombre_apellido'
#print(tarjeta_personal)
tarjeta_personal.pop('apellido')
#print(tarjeta_personal)

tarjeta_personal['nombre_apellido'] = input('ingrese el dato nuevo')
print(tarjeta_personal)
# Out:
# {'nombre': 'lucas', 'apellido': 'gimenez', 'telefono': '0985-350656', 'direccion': 'lambare'}
# {'nombre': 'lucas', 'telefono': '0985-350656', 'direccion': 'lambare', 'nombre_apellido': 'lucas'}

# %% [markdown]
# # Challenge 3 🤺
# Crear una agenda de contactos. El usuario puede elegir:
#
# Mostrar los contactos
# Crear contacto
# Modificar datos del contacto
#
# 1- crear una agenda de contactos -----> contacto ={}
# 2- print(contactos)
# 3- crear los contactos ------> contactos [clave] = input('ingrese el valor de la clave')
# 4-  crear el valor (value) de la clave ---> contactos[value] = input('ingrese el dato:)
# 5- modificar dATOS DEL CONTACTO ---> contactos['VALUE'] = "nuevo dato"

# %% [markdown]
# Challenge 🤺  - 15 min
# Crear una clase animales que tenga atributo de clase y de instancia.
#
# Atributos de clase: especie.
# Atributos de instancia: nombre & color
# .
# Luego, crear nuevos objetos a partir de las nuevas class. Imprimir el nombre y el color de los animales en una frase.
# Ejemplo: "Me llamo {nombre} y soy un ave de color {color}".

# %% [markdown]
# #1-  ATRIBUTO DE CLASE (CLASS) ESPECIE
#
# 2- ATRIBUTOS DE INSTANCIA (DEF) - NOMBRE Y COLOR
# 3- LUEGO CREAR OBJETOS ----> SELF -- __INIT__
# 4- IMPRIMI EL NOMBRE Y EL COLOR DE LOS ANIMALES EN UNA FRASE ---

# %%
class Perro:
    especie = "Canina"

# definir el metodo constructor, inicializa 
    def __init__(self, nombre, color):
        self.nombre = nombre
        self.color = color

#instanciar el objeto
duke = Perro('bellita','negro')

print(f'Me llamo:{duke.nombre} y soy can de color {duke.color}')
# Out:
# Me llamo:bellita y soy can de color negro

# %% [markdown]
# Crear dos métodos para nuestro animal y ejecutar, debe ser algo específico de ese animal.
#
# Ejemplo: "Cuando hablo, digo X".
# Ejemplo: "Cuando me muevo, hago X".

# %%
class Perro:
    especie = 'canina'

    def __init__(self,nombre,color):
        self.nombre = nombre
        self.color = color
    
duke = Perro ('duke', 'manto negro')

def ladrar(self,sonido):
        print(f'cuando ladro hago{sonido}')
    
def mover(self, bruto):
        print(f'Cuando me muevo soy muy {bruto}')
duke.ladrar('guau guau guau')
duke.mover('bruto')

# %% [markdown]
# # herencia
#
#
# class AninalDeGranja:
#  # atributos de clases
#  tipo = 'animal de granja'
#
#  # atributos de instancia
#   def __init__(self, nombre, color, sonido)
#   self.nombre = nombre
#   self.color = color
#   self.sonido = sonido
#
# # metodos (acciones de la clase)
#
# def hablar(self):
# print(f' Hablo y digo {self.sonido}')
#
#
# def presentarse (self):
# print(f'hola, soy{self.nombre})
#
#
# class Gallina

# %% [markdown]
# Challenge 3🤺 - 15 min
# Definir una clase madre que herede a sus clases hijas dos atributos de instancia. Mostrar ambos atributos en pantalla desde los objetos de las clases hijas.
#
# Observación: Editar las clases hijas para que no se inicialicen.

# %%
class Lacteos:
    tipo = 'Lacteos'
    def __init__(self, nombre, presentacion, tamanho):
        self.nombre = nombre
        self.presentacion = presentacion
        self.tamanho = tamanho



class Yogurt(Lacteos):
    yogurt = 'frutilla'

    def tamano(self):
        print(f' el tamano es {self.tamanho}')

class Queso(Lacteos):
    queso = 'roquefort'

    def tipo(self):
        print(f'el queso es tipo: {self.nombre},{self.presentacion},{self.tamanho}')

leche = Yogurt('lactolanda', 'vaso', 'chico')

leche.tamano()
jamon = Queso ('trebol', 'fetas', '250 gr')

jamon.tipo()
# Out:
#  el tamano es chico
# el queso es tipo: trebol,fetas,250 gr

# %% [markdown]
# # Challenge 4 🤺 - 20 min
# Crear dos personajes de una historia que se representen a traves de clases. Ejemplo: Un hereo y un villano.
# Cada personaje debe tener poderes o acciones diferentes. Y deben presentarse en una frase.
#
# Ejemplo: Yo me llamo pepito y tengo super fuerza
# Ejemplo: Yo me llamo juanito y puedo volar

# %% [markdown]
# crear la clase madre 'caperucita_roja'
#
#
# crear un heroe = la abuela
# la abuela tiene vision laser, mucha fuerza
#
# crear un villano = el lobo
# el lobo tiene el poder de soplar fuerte y de disfrazarse

# %%
class Caperucita_roja:
    tipo = 'Cuentos'

    def __init__(self, nombre, trama):
        self.nombre = nombre
        self.trama = trama


class Villano(Caperucita_roja):
    Villano = 'alias1'
    def tipo(self):
        print(f'Yo me llamo: {self.nombre} y tengo este poder: {}')
