# %%
print ('Hola Mundo')
# Out:
# Hola Mundo

# %%
#snake_case:
frase_famosa = 'Hola mundo'

# %%
# #Orden de Ejecucion
# fruta = 'naranja'
# print(fruta)

# cantidad_de_frutas = 4
# print(cantidad_de_frutas)

# fruta = 'banana'
# print(fruta)
# Out:
# naranja
# 4
# banana

# %% [markdown]
# tipos de datos

# %%
# edad = 28 # --> Integer
# altura = 1.80 # --> float
# nombre = "Lucas" # --> String
# feliz = True # bool

# # print(nombre)     #para comentar las lineas control + k y control + c, para descomentar control k y control u
# # print(edad)
# # print(altura)
# # print(feliz)
# print(edad, altura,edad, nombre)
# Out:
# 28 1.8 28 Lucas

# %%
# Nombre = 'Lucas'
# Edad = 42
# Ciudad = 'Lambare'

# print ('Mi nombre es:' ,Nombre, ', Tengo :', Edad,'anos', ', vivo en la ciudad de:', Ciudad)
# Out:
# Mi nombre es: Lucas , Tengo : 42 anos , vivo en la ciudad de: Lambare

# %%
# producto1 = 'papas fritas'
# costo_producto1 = 15000
# producto2 = 'coca cola'
# costo_producto2 = 14000
# capital = 50000
# dolar = 6700

# # Realizamos la suma
# costo_total = costo_producto1 + costo_producto2
# print(costo_total)

# # realizamos la resta
# vuelto = capital - costo_total
# print(vuelto)

# # realizamos la division
# vuelto_dolar = vuelto // dolar   #division entera sin decimales
# print(vuelto_dolar)
# Out:
# 29000
# 21000
# 3

# %%
# # declaracion de variables
# cantidad_de_manzanas = 15
# cantidad_de_naranjas = 20
# frutas_vendidas = 12

# # realizamos la suma de la variables
# cantidad_de_frutas = cantidad_de_manzanas + cantidad_de_naranjas
# print('el total de frutas es:',cantidad_de_frutas)

# # realizamos la resta de la nueva variables con el primer resultado.
# frutas_restantes = cantidad_de_frutas - frutas_vendidas
# print('Nos quedan:', frutas_restantes, 'frutas')
# Out:
# el total de frutas es: 35
# Nos quedan: 23 frutas

# %%
# nombre = "lucas"
# apellido = 'Gimenez'
# espacio = ' ' 

# # print(nombre)
# # print(apellido)

# # print(nombre + apellido)
# # print(nombre + ' ' + apellido)
# # print(nombre + espacio + apellido)

# #agregar el print con f
# print(f'mi nombre es: {nombre} y mi apellido es: {apellido}')
# Out:
# mi nombre es: lucas y mi apellido es: Gimenez

# %%
# nombre = 'Benjamin'
# apellido = 'Cabrera'

# print(f'hola, me llamo {nombre}  {apellido}, mucho gusto!!')
# Out:
# hola, me llamo Benjamin  Cabrera, mucho gusto!!

# %% [markdown]
# ### el imput sirve para que el programa le pregunte al usuario y guarde lo que responde por teclado

# %%
nombre = input("Escribe tu nombre")
print(nombre)
# Out:
# lucas

# %%
# solicitar al usuario un producto
producto = input("Que producto deseas")
print(producto)


# Solicitar al usario que ingrese la cantidad
cantidad_de_producto = input('que cantidad de producto deseas')
print(cantidad_de_producto)

print(f'El usuario quiere {producto} en {cantidad_de_producto} cantidades')
# Out:
# coca cola
# 34
# El usuario quiere coca cola en 34 cantidades

# %%
edad = 34
print (type(edad))

nombre = 'lucas'
print (type(nombre))

temperatura = 36.5
print (type(temperatura))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'float'>

# %%
# edad = input('cuantos anhos tienes')
# print (type(edad))

# cantidad_de_anhos = int (edad)
# print(type(cantidad_de_anhos))

# temperatura = input('cual es la temperatura actual')
# print(type(temperatura))
# print(temperatura)
# Out:
# <class 'str'>
# <class 'int'>

# %%
numero1 = int(input('ingrese el primer numero')) #pasar un str a int
print(type(numero1))
numero2 = int(input('ingrese el segundo numero'))
print(type(numero2))

suma = numero1 + numero2
print(suma)
# Out:
# <class 'int'>
# <class 'int'>
# 11

# %% [markdown]
# ## funciones
# ## es un bloque de codigo reutilizable que ejecuta una tarea cuando se invoca o se llama. se define con la palabra clave "def".

# %%
# aca definimos la funcion

def preparar_sandwich():
    print('Preparar sandwich')
    print('el sandwich ya esta casi listo')

# aqui termina la funcion

# llamar a la funcion
preparar_sandwich()
# Out:
# Preparar sandwich
# el sandwich ya esta casi listo

# %%
#callenge de funcion

#definimos la funcion

def preparar_chupin_de_surubi():
    print('Preparar Chupin de Surubi')
    print('1- cortar en rodajas el surubi \n','2- Cortas las verdurad, no muy chicas \n','3- Colocar todo en la chupinera \n')
    print('A disfrutar')

preparar_chupin_de_surubi()
preparar_chupin_de_surubi()
preparar_chupin_de_surubi()
# Out:
# Preparar Chupin de Surubi
# 1- cortar en rodajas el surubi
#  2- Cortas las verdurad, no muy chicas
#  3- Colocar todo en la chupinera
#
# A disfrutar
# Preparar Chupin de Surubi
# 1- cortar en rodajas el surubi
#  2- Cortas las verdurad, no muy chicas
#  3- Colocar todo en la chupinera
#
# A disfrutar
# Preparar Chupin de Surubi
# 1- cortar en rodajas el surubi
#  2- Cortas las verdurad, no muy chicas
#  3- Colocar todo en la chupinera
#
# A disfrutar

# %% [markdown]
# ## funciones con parametros y argumentos

# %%
#CHALLENGE

def compra(elemento,caracteristicas):
    print(f )
    elemento = input('Indique que precisa:')
    caracteristicas = input('indique que caracteristicas necesita:')
    

compra()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[60], line 8
#       5     caracteristicas = input('indique que caracteristicas necesita:')
#       6     print(f'tu producto es:{producto} , tiene las sgtes caracteristicas:{caracteristicas}')
# ----> 8 compra()
#
# TypeError: compra() missing 1 required positional argument: 'caracteristicas'

# %%
# Challenge 6 del companero
# Escribir una funcion que nos pregunte las caracteristicas de un elemento a comprar e imprima el elemento con sus caracteristicas.

def mostrar_producto(elemento, primera_caracteristica, segunda_caracteristica, tercera_caracteristica):
    print(f"El elemento a comprar es {elemento}, y cuenta con las siguientes caracteristicas: {primera_caracteristica}, {segunda_caracteristica}, {tercera_caracteristica}")

def producto_a_comprar():
    elemento = input("Ingrese el elemento a comprar: ")
    primera_caracteristica = input("Ingrese una caracteristica del elemento a comprar: ")
    segunda_caracteristica = input("Ingrese otra caracteristica del elemento a comprar: ")
    tercera_caracteristica = input("Ingrese una ultima caracteristica del elemento a comprar: ")

    mostrar_producto(elemento, primera_caracteristica, segunda_caracteristica, tercera_caracteristica)

producto_a_comprar()

# %%
tipo = input('ingrese el tipo de producto')

def pregunta(producto):
    tamanho = input('ingrese el tamanho:'),
    color = input('ingrese el color:'),

    print('el tipo es:', tipo, 'el tamanho elegido es:', tamanho, 'su color es:', color)

pregunta(producto)



#del companero


pulgadas = input("¿Cuántas pulgadas es la television")
def preguntar():
    resolucion = input("¿Cuál es la resolución que tiene la TV")
    print(f"La TV tiene {pulgadas} pulgadas y una resolucion de {resolucion}")

preguntar()
# Out:
# el tipo es: remera el tamanho elegido es: ('xg',) su color es: ('amarillo',)
